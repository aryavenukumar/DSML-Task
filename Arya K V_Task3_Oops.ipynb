# %% [markdown]
# 1.  Write a Python program to create a class representing a Circle. Include methods to calculate its area and perimeter.

# %%
import math
class Circle:
  radius=0.0
  pi=math.pi


  def area(self):
    print("area of circle:",self.pi*self.radius**2)
  def perimeter(self):
    print("perimeter of circle:",2*self.pi*self.radius)
circle1=Circle()
circle1.radius=14
circle1.area()
circle1.perimeter()
# Out:
# area of circle: 615.7521601035994
# perimeter of circle: 87.96459430051421

# %% [markdown]
# 2. Write a Python program to create a calculator class. Include methods for basic arithmetic operations.

# %%
class Calculator:
  def add(self,num1,num2):
    return num1+num2
  def sub(self,num1,num2):
    return num1-num2
  def multiply(self,num1,num2):
    return num1*num2
  def division(self,num1,num2):
    if num2==0:
      print("cannot be divisible by zero")
    return num1/num2

calculator1=Calculator()
addition=calculator1.add(14,6)
subtraction=calculator1.sub(22,10)
multiplication=calculator1.multiply(8,4)
division=calculator1.division(24,2)

print("addition=",addition)
print("subtraction=",subtraction)
print("multiplication=",multiplication)
print("division=",division)
# Out:
# addition= 20
# subtraction= 12
# multiplication= 32
# division= 12.0

# %% [markdown]
# 3. Write a Python program to create a class that represents a shape. Include methods to calculate its area and perimeter. Implement subclasses for different shapes like circle, triangle, and square.

# %%
import math
class Shape:
  def area(self):
    pass
  def perimeter(self):
    pass
class Circle(Shape):
  def __init__(self,radius):
    self.radius=radius
  def area(self):
    print("area of circle:",math.pi*self.radius**2)
  def perimeter(self):
    print("perimeter of circle:",2*math.pi*self.radius)
circle1=Circle(radius=8)
circle1.area()
circle1.perimeter()

class Triangle(Shape):
  def __init__(self,side1,side2,side3):
    self.side1=side1
    self.side2=side2
    self.side3=side3
  def area(self):
    s = (self.side1 + self.side2 + self.side3) / 2
    print("area of triangle:",math.sqrt(s * (s - self.side1) * (s - self.side2) * (s - self.side3)))
  def perimeter(self):
    print("perimeter of triangle:",self.side1 + self.side2 + self.side3)
triangle1=Triangle(side1=3,side2=5,side3=4)
triangle1.area()
triangle1.perimeter()

class Square(Shape):
  def __init__(self,side):
    self.side=side
  def area(self):
    print("area of square:",self.side**2)
  def perimeter(self):
    print("perimeter of square:",4*self.side)
square1=Square(side=5)
square1.area()
square1.perimeter()
# Out:
# area of circle: 201.06192982974676
# perimeter of circle: 50.26548245743669
# area of triangle: 6.0
# perimeter of triangle: 12
# area of square: 25
# perimeter of square: 20
